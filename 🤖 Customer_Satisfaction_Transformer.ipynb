# %% [markdown]
# # Customer_Satisfaction_Transformer
#
# 🎯 Purpose: Predict satisfaction rating (1–5) using DistilBERT fine-tuning.
#
# ⚙️ Run on Google Colab GPU or a local GPU environment.

# %% [markdown]
# # Install dependencies

# %%
# !pip install torch scikit-learn --quiet
# !pip install -U transformers
# Out:
# Requirement already satisfied: transformers in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (4.57.1)
# Requirement already satisfied: filelock in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kaushlendra p singh\anaconda3\lib\site-packages (from requests->transformers) (2025.4.26)

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.57.1

# %% [markdown]
# # Load dataset

# %%
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments

# %%
import warnings
warnings.filterwarnings('ignore')

import os
os.environ["HF_HUB_DISABLE_SYMLINKS_WARNING"] = "1"

# %%
# Load data

df = pd.read_csv("customer_support_tickets.csv")

# %%
# Keep only rows with valid satisfaction rating
df = df[df['Customer Satisfaction Rating'].notna()]
df['label'] = df['Customer Satisfaction Rating'].astype(int) - 1

# %%
# Combine text fields
df['text'] = df['Ticket Subject'].fillna('') + ' ' + df['Ticket Description'].fillna('')

# %%
print("Dataset shape:", df.shape)
df[['text', 'label']].head()
# Out:
# Dataset shape: (2769, 19)
#                                                  text  label
# 2   Network problem I'm facing a problem with my {...      2
# 3   Account access I'm having an issue with the {p...      2
# 4   Data loss I'm having an issue with the {produc...      0
# 10  Data loss I'm having an issue with the {produc...      0
# 11  Software bug I'm having an issue with the {pro...      0

# %% [markdown]
# # Tokenization

# %%
# Split dataset
train_texts, val_texts, train_labels, val_labels = train_test_split(
    df['text'], df['label'], test_size=0.2, stratify=df['label'], random_state=42
)

# %%
# Load tokenizer
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained('distilbert-base-uncased')

# %%
# Tokenize
train_encodings = tokenizer(train_texts.tolist(), truncation=True, padding=True, max_length=128)
val_encodings = tokenizer(val_texts.tolist(), truncation=True, padding=True, max_length=128)

# %% [markdown]
# # Prepare PyTorch Dataset

# %%
class CSATDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels
    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels.iloc[idx])
        return item
    def __len__(self):
        return len(self.labels)

train_dataset = CSATDataset(train_encodings, train_labels)
val_dataset = CSATDataset(val_encodings, val_labels)

# %% [markdown]
# # Load model and train

# %%
from transformers import AutoModelForSequenceClassification, Trainer, TrainingArguments

model = AutoModelForSequenceClassification.from_pretrained(
    'distilbert-base-uncased',
    num_labels=5
)

training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=2,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    logging_dir='./logs',
    load_best_model_at_end=True,
    evaluation_strategy="epoch",   # or "steps"
    logging_strategy="steps",
    logging_steps=100,
    save_strategy="epoch"          # ensures checkpoints are saved
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)

trainer.train()
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       1 from transformers import AutoModelForSequenceClassification, Trainer, TrainingArguments
#       3 model = AutoModelForSequenceClassification.from_pretrained(
#       4     'distilbert-base-uncased',
#       5     num_labels=5
#       6 )
# ----> 8 training_args = TrainingArguments(
#       9     output_dir='./results',
#      10     num_train_epochs=2,
#      11     per_device_train_batch_size=8,
#      12     per_device_eval_batch_size=8,
#      13     logging_dir='./logs',
#      14     load_best_model_at_end=True,
#      15     evaluation_strategy="steps",   # or "steps"
#      16     logging_strategy="steps",
#      17     logging_steps=100,
#      18     save_strategy="epoch"          # ensures checkpoints are saved
#      19 )
#      21 trainer = Trainer(
#      22     model=model,
#      23     args=training_args,
#      24     train_dataset=train_dataset,
#      25     eval_dataset=val_dataset,
#      26 )
#      28 trainer.train()
#
# TypeError: TrainingArguments.__init__() got an unexpected keyword argument 'evaluation_strategy'

# %% [markdown]
# # Evaluate & Save Model

# %%
# Evaluation
predictions = trainer.predict(val_dataset)
y_pred = predictions.predictions.argmax(axis=1)

print(classification_report(val_labels, y_pred))

# %%
# Save model
model.save_pretrained('/mnt/data/csat_distilbert_model/')
tokenizer.save_pretrained('/mnt/data/csat_distilbert_model/')
print("✅ Model saved to /mnt/data/csat_distilbert_model/")

# %%
print(transformers.__version__
